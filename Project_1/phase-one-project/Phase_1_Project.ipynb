# %% [markdown]
# # Importing Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %% [markdown]
# # Importing Datafiles

# %% [markdown]
# ## 'Basics' File

# %%
basics_df = pd.read_csv('zippedData/imdb.title.basics.csv.gz')
basics_df.head()
basics_df.info()
basics_df.shape
# Out:
#       tconst                    primary_title              original_title  \
# 0  tt0063540                        Sunghursh                   Sunghursh
# 1  tt0066787  One Day Before the Rainy Season             Ashad Ka Ek Din
# 2  tt0069049       The Other Side of the Wind  The Other Side of the Wind
# 3  tt0069204                  Sabse Bada Sukh             Sabse Bada Sukh
# 4  tt0100275         The Wandering Soap Opera       La Telenovela Errante
#
#    start_year  runtime_minutes                genres
# 0        2013            175.0    Action,Crime,Drama
# 1        2019            114.0       Biography,Drama
# 2        2018            122.0                 Drama
# 3        2018              NaN          Comedy,Drama
# 4        2017             80.0  Comedy,Drama,Fantasy
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146144 entries, 0 to 146143
# Data columns (total 6 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   tconst           146144 non-null  object
#  1   primary_title    146144 non-null  object
#  2   original_title   146123 non-null  object
#  3   start_year       146144 non-null  int64
#  4   runtime_minutes  114405 non-null  float64
#  5   genres           140736 non-null  object
# dtypes: float64(1), int64(1), object(4)
# memory usage: 6.7+ MB
# (146144, 6)

# %% [markdown]
# ## 'Budgets Datafile

# %%
budgets_df = pd.read_csv('zippedData/tn.movie_budgets.csv.gz')
budgets_df.head()
budgets_df.info()
budgets_df.shape
# Out:
#    id  release_date                                        movie  \
# 0   1  Dec 18, 2009                                       Avatar
# 1   2  May 20, 2011  Pirates of the Caribbean: On Stranger Tides
# 2   3   Jun 7, 2019                                 Dark Phoenix
# 3   4   May 1, 2015                      Avengers: Age of Ultron
# 4   5  Dec 15, 2017            Star Wars Ep. VIII: The Last Jedi
#
#   production_budget domestic_gross worldwide_gross
# 0      $425,000,000   $760,507,625  $2,776,345,279
# 1      $410,600,000   $241,063,875  $1,045,663,875
# 2      $350,000,000    $42,762,350    $149,762,350
# 3      $330,600,000   $459,005,868  $1,403,013,963
# 4      $317,000,000   $620,181,382  $1,316,721,747
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5782 entries, 0 to 5781
# Data columns (total 6 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5782 non-null   int64
#  1   release_date       5782 non-null   object
#  2   movie              5782 non-null   object
#  3   production_budget  5782 non-null   object
#  4   domestic_gross     5782 non-null   object
#  5   worldwide_gross    5782 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 271.2+ KB
# (5782, 6)

# %% [markdown]
# ## 'Ratings' Datafile

# %%
ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
ratings_df.head()
ratings_df.info()
ratings_df.shape
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# (73856, 3)

# %% [markdown]
# # Data Preparation

# %% [markdown]
# ## Preparing 'Basics'
#
#         - Drop extraneous columns
#         - Fill missing runtime entries with median runtime
#         - Drop missing genre rows

# %%
basics_df.isna().sum()
# Out:
# tconst                 0
# primary_title          0
# original_title        21
# start_year             0
# runtime_minutes    31739
# genres              5408
# dtype: int64

# %%
basics_df.drop(columns='original_title', inplace=True)

# %%
runtime_median = basics_df['runtime_minutes'].median()

basics_df = basics_df.fillna(value={'runtime_minutes': runtime_median})
basics_df
# Out:
#            tconst                                primary_title  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146142  tt9916730                                       6 Gunn        2017
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                genres
# 0                 175.0    Action,Crime,Drama
# 1                 114.0       Biography,Drama
# 2                 122.0                 Drama
# 3                  87.0          Comedy,Drama
# 4                  80.0  Comedy,Drama,Fantasy
# ...                 ...                   ...
# 146139            123.0                 Drama
# 146140             87.0           Documentary
# 146141             87.0                Comedy
# 146142            116.0                   NaN
# 146143             87.0           Documentary
#
# [146144 rows x 5 columns]

# %%
basics_df = basics_df.dropna()

# %%
basics_df.isna().sum()
# Out:
# tconst             0
# primary_title      0
# start_year         0
# runtime_minutes    0
# genres             0
# dtype: int64

# %% [markdown]
# ## Preparing 'Budgets'
#
#     - Remove special characters from budget, domestic, and worldwide gross columns
#     - Change above columns datatype to int
#     - Drop unnecessary columns
#     - Remove rows with zeroes in domestic and worldwide gross

# %%
budgets_df = budgets_df.replace(r'[$,]', '', regex=True)
budgets_df
# Out:
#       id release_date                                        movie  \
# 0      1  Dec 18 2009                                       Avatar
# 1      2  May 20 2011  Pirates of the Caribbean: On Stranger Tides
# 2      3   Jun 7 2019                                 Dark Phoenix
# 3      4   May 1 2015                      Avengers: Age of Ultron
# 4      5  Dec 15 2017            Star Wars Ep. VIII: The Last Jedi
# ...   ..          ...                                          ...
# 5777  78  Dec 31 2018                                       Red 11
# 5778  79   Apr 2 1999                                    Following
# 5779  80  Jul 13 2005                Return to the Land of Wonders
# 5780  81  Sep 29 2015                         A Plague So Pleasant
# 5781  82   Aug 5 2005                            My Date With Drew
#
#      production_budget domestic_gross worldwide_gross
# 0            425000000      760507625      2776345279
# 1            410600000      241063875      1045663875
# 2            350000000       42762350       149762350
# 3            330600000      459005868      1403013963
# 4            317000000      620181382      1316721747
# ...                ...            ...             ...
# 5777              7000              0               0
# 5778              6000          48482          240495
# 5779              5000           1338            1338
# 5780              1400              0               0
# 5781              1100         181041          181041
#
# [5782 rows x 6 columns]

# %%
budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']] = budgets_df[['production_budget', 'domestic_gross', 'worldwide_gross']].apply(pd.to_numeric)
           
budgets_df.dtypes
# Out:
# id                    int64
# release_date         object
# movie                object
# production_budget     int64
# domestic_gross        int64
# worldwide_gross       int64
# dtype: object

# %%
budgets_df = budgets_df.drop(['id', 'release_date'], axis=1)
budgets_df
# Out:
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4               Star Wars Ep. VIII: The Last Jedi          317000000
# ...                                           ...                ...
# 5777                                       Red 11               7000
# 5778                                    Following               6000
# 5779                Return to the Land of Wonders               5000
# 5780                         A Plague So Pleasant               1400
# 5781                            My Date With Drew               1100
#
#       domestic_gross  worldwide_gross
# 0          760507625       2776345279
# 1          241063875       1045663875
# 2           42762350        149762350
# 3          459005868       1403013963
# 4          620181382       1316721747
# ...              ...              ...
# 5777               0                0
# 5778           48482           240495
# 5779            1338             1338
# 5780               0                0
# 5781          181041           181041
#
# [5782 rows x 4 columns]

# %%
budgets_df = budgets_df.drop(budgets_df.loc[(budgets_df['domestic_gross']==0) & 
                                            (budgets_df['worldwide_gross']==0)].index)
budgets_df
# Out:
#                                             movie  production_budget  \
# 0                                          Avatar          425000000
# 1     Pirates of the Caribbean: On Stranger Tides          410600000
# 2                                    Dark Phoenix          350000000
# 3                         Avengers: Age of Ultron          330600000
# 4               Star Wars Ep. VIII: The Last Jedi          317000000
# ...                                           ...                ...
# 5775                                       Cavite               7000
# 5776                              The Mongol King               7000
# 5778                                    Following               6000
# 5779                Return to the Land of Wonders               5000
# 5781                            My Date With Drew               1100
#
#       domestic_gross  worldwide_gross
# 0          760507625       2776345279
# 1          241063875       1045663875
# 2           42762350        149762350
# 3          459005868       1403013963
# 4          620181382       1316721747
# ...              ...              ...
# 5775           70071            71644
# 5776             900              900
# 5778           48482           240495
# 5779            1338             1338
# 5781          181041           181041
#
# [5415 rows x 4 columns]

# %%
budgets_df.isna().sum()
budgets_df.isnull().sum()
# Out:
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64
# movie                0
# production_budget    0
# domestic_gross       0
# worldwide_gross      0
# dtype: int64

# %% [markdown]
# ## 'Ratings' Datafile
#
#     -Check for NaN and null, dtype
#     -Merge with basics

# %%
ratings_df = pd.read_csv('zippedData/imdb.title.ratings.csv.gz')
ratings_df.head()
ratings_df.info()
ratings_df.shape
# Out:
#        tconst  averagerating  numvotes
# 0  tt10356526            8.3        31
# 1  tt10384606            8.9       559
# 2   tt1042974            6.4        20
# 3   tt1043726            4.2     50352
# 4   tt1060240            6.5        21
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73856 entries, 0 to 73855
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         73856 non-null  object
#  1   averagerating  73856 non-null  float64
#  2   numvotes       73856 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 1.7+ MB
# (73856, 3)

# %%
ratings_df.isna().sum()
ratings_df.isnull().sum()
ratings_df.dtypes
# Out:
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64
# tconst           0
# averagerating    0
# numvotes         0
# dtype: int64
# tconst            object
# averagerating    float64
# numvotes           int64
# dtype: object

# %% [markdown]
# ## Creating merged DF 'basics_ratings'

# %%
basics_ratings_df =  ratings_df.merge(basics_df, how='inner', on='tconst')
basics_ratings_df
# Out:
#            tconst  averagerating  numvotes  \
# 0      tt10356526            8.3        31
# 1      tt10384606            8.9       559
# 2       tt1042974            6.4        20
# 3       tt1043726            4.2     50352
# 4       tt1060240            6.5        21
# ...           ...            ...       ...
# 73047   tt9805820            8.1        25
# 73048   tt9844256            7.5        24
# 73049   tt9851050            4.7        14
# 73050   tt9886934            7.0         5
# 73051   tt9894098            6.3       128
#
#                                            primary_title  start_year  \
# 0                                       Laiye Je Yaarian        2019
# 1                                             Borderless        2019
# 2                                              Just Inès        2010
# 3                                 The Legend of Hercules        2014
# 4                                              Até Onde?        2011
# ...                                                  ...         ...
# 73047                                              Caisa        2018
# 73048  Code Geass: Lelouch of the Rebellion - Glorifi...        2018
# 73049                                            Sisters        2019
# 73050                                  The Projectionist        2019
# 73051                                             Sathru        2019
#
#        runtime_minutes                    genres
# 0                117.0                   Romance
# 1                 87.0               Documentary
# 2                 90.0                     Drama
# 3                 99.0  Action,Adventure,Fantasy
# 4                 73.0          Mystery,Thriller
# ...                ...                       ...
# 73047             84.0               Documentary
# 73048            120.0   Action,Animation,Sci-Fi
# 73049             87.0              Action,Drama
# 73050             81.0               Documentary
# 73051            129.0                  Thriller
#
# [73052 rows x 7 columns]

# %% [markdown]
# ## Creating merged DF 'budgets_basics'
#
#     -Requires column name change before merge
#     -Change primary_title to movie in basics df
#     -Merge on 'movie'

# %%
basics_df.rename(columns={'primary_title': 'movie'}, inplace=True)
basics_df
# Out:
# C:\Users\mcn92\anaconda3\envs\learn-env\lib\site-packages\pandas\core\frame.py:4441: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
#            tconst                                        movie  start_year  \
# 0       tt0063540                                    Sunghursh        2013
# 1       tt0066787              One Day Before the Rainy Season        2019
# 2       tt0069049                   The Other Side of the Wind        2018
# 3       tt0069204                              Sabse Bada Sukh        2018
# 4       tt0100275                     The Wandering Soap Opera        2017
# ...           ...                                          ...         ...
# 146138  tt9916428                          The Secret of China        2019
# 146139  tt9916538                          Kuambil Lagi Hatiku        2019
# 146140  tt9916622  Rodolpho Teóphilo - O Legado de um Pioneiro        2015
# 146141  tt9916706                              Dankyavar Danka        2013
# 146143  tt9916754               Chico Albuquerque - Revelações        2013
#
#         runtime_minutes                 genres
# 0                 175.0     Action,Crime,Drama
# 1                 114.0        Biography,Drama
# 2                 122.0                  Drama
# 3                  87.0           Comedy,Drama
# 4                  80.0   Comedy,Drama,Fantasy
# ...                 ...                    ...
# 146138             87.0  Adventure,History,War
# 146139            123.0                  Drama
# 146140             87.0            Documentary
# 146141             87.0                 Comedy
# 146143             87.0            Documentary
#
# [140736 rows x 5 columns]

# %%
basic_budgets_df = basics_df.merge(budgets_df, how='inner', on='movie')
basic_budgets_df
# Out:
#          tconst                movie  start_year  runtime_minutes  \
# 0     tt0249516           Foodfight!        2012             91.0
# 1     tt0293429        Mortal Kombat        2021             87.0
# 2     tt0337692          On the Road        2012            124.0
# 3     tt2404548          On the Road        2011             90.0
# 4     tt3872966          On the Road        2013             87.0
# ...         ...                  ...         ...              ...
# 3357  tt9678962                 Fuel        2018             87.0
# 3358  tt9729206                Diner        2019             87.0
# 3359  tt9805168              Traitor        2015            110.0
# 3360  tt9844102                  Ray        2018            111.0
# 3361  tt9889814  Kiss Kiss Bang Bang        2017             98.0
#
#                         genres  production_budget  domestic_gross  \
# 0      Action,Animation,Comedy           45000000               0
# 1     Action,Adventure,Fantasy           20000000        70433227
# 2      Adventure,Drama,Romance           25000000          720828
# 3                        Drama           25000000          720828
# 4                  Documentary           25000000          720828
# ...                        ...                ...             ...
# 3357         Documentary,Sport            2500000          174255
# 3358                     Crime            5000000        12592907
# 3359      Action,Drama,Romance           22000000        23530831
# 3360                     Crime           40000000        75305995
# 3361    Crime,Romance,Thriller           15000000         4235837
#
#       worldwide_gross
# 0               73706
# 1           122133227
# 2             9313302
# 3             9313302
# 4             9313302
# ...               ...
# 3357           174255
# 3358         12592907
# 3359         27882226
# 3360        124823094
# 3361         16829464
#
# [3362 rows x 8 columns]

# %% [markdown]
# # Analysis
#
# ## Does a film's budget affect its gross revenue?

# %%
# Generate scatterplot of production_budget vs worldwide_gross. We use worldwide
# because it already takes domestic gross into account

plt.figure(figsize=(12,8))
ax = sns.regplot(x='production_budget', y='worldwide_gross',data=basic_budgets_df, line_kws={'color':'red'})

plt.title('Budget vs. Gross')
ax.set_xlabel('Production Budget', fontsize= 20)
ax.set_ylabel('Worldwide Gross', fontsize= 20)
ax.set_title('Budget vs Worldwide Gross in Billions USD', fontsize=26)
plt.xticks(weight='bold')
plt.yticks(weight='bold');

# %%
# Calculate correlation coefficient to support trend in visualization
np.corrcoef(basic_budgets_df['production_budget'], basic_budgets_df['worldwide_gross'])
# Out:
# array([[1.       , 0.7602276],
#        [0.7602276, 1.       ]])

# %% [markdown]
# ## Does profitability vary by genre?
#
#     - Create profit column
#     - Calculate and create profitability column
#     - Split multi-value genres into single genres and groupby
#     - Create plot of genre vs profitability

# %%
basic_budgets_df['profit'] = basic_budgets_df['worldwide_gross'] - basic_budgets_df['production_budget']
basic_budgets_df
# Out:
#          tconst                movie  start_year  runtime_minutes  \
# 0     tt0249516           Foodfight!        2012             91.0
# 1     tt0293429        Mortal Kombat        2021             87.0
# 2     tt0337692          On the Road        2012            124.0
# 3     tt2404548          On the Road        2011             90.0
# 4     tt3872966          On the Road        2013             87.0
# ...         ...                  ...         ...              ...
# 3357  tt9678962                 Fuel        2018             87.0
# 3358  tt9729206                Diner        2019             87.0
# 3359  tt9805168              Traitor        2015            110.0
# 3360  tt9844102                  Ray        2018            111.0
# 3361  tt9889814  Kiss Kiss Bang Bang        2017             98.0
#
#                         genres  production_budget  domestic_gross  \
# 0      Action,Animation,Comedy           45000000               0
# 1     Action,Adventure,Fantasy           20000000        70433227
# 2      Adventure,Drama,Romance           25000000          720828
# 3                        Drama           25000000          720828
# 4                  Documentary           25000000          720828
# ...                        ...                ...             ...
# 3357         Documentary,Sport            2500000          174255
# 3358                     Crime            5000000        12592907
# 3359      Action,Drama,Romance           22000000        23530831
# 3360                     Crime           40000000        75305995
# 3361    Crime,Romance,Thriller           15000000         4235837
#
#       worldwide_gross     profit
# 0               73706  -44926294
# 1           122133227  102133227
# 2             9313302  -15686698
# 3             9313302  -15686698
# 4             9313302  -15686698
# ...               ...        ...
# 3357           174255   -2325745
# 3358         12592907    7592907
# 3359         27882226    5882226
# 3360        124823094   84823094
# 3361         16829464    1829464
#
# [3362 rows x 9 columns]

# %%
basic_budgets_df.dropna(axis=1, inplace=True)

# %%
basic_budgets_df['profitability'] = ((basic_budgets_df['profit']) / (basic_budgets_df['worldwide_gross'])) * 100
basic_budgets_df['profitability']= basic_budgets_df['profitability'].astype(int)
basic_budgets_df.sort_values(['profitability'], ascending=False).head()
# Out:
#          tconst                            movie  start_year  runtime_minutes  \
# 3307  tt9691476  Snow White and the Seven Dwarfs        2016             87.0
# 3306  tt7821084  Snow White and the Seven Dwarfs        2017             49.0
# 2286  tt2309260                      The Gallows        2015             81.0
# 1026  tt1502407                        Halloween        2018            106.0
# 2528  tt2668120                            Bambi        2013             58.0
#
#                        genres  production_budget  domestic_gross  \
# 3307     Comedy,Drama,Fantasy            1488000       184925486
# 3306         Animation,Family            1488000       184925486
# 2286  Horror,Mystery,Thriller             100000        22764410
# 1026          Horror,Thriller             325000        47000000
# 2528    Biography,Documentary             858000       102797000
#
#       worldwide_gross     profit  profitability
# 3307        184925486  183437486             99
# 3306        184925486  183437486             99
# 2286         41656474   41556474             99
# 1026         70000000   69675000             99
# 2528        268000000  267142000             99

# %%
genre_df = basic_budgets_df.copy()

split_genre = genre_df['genres'].str.split(',').apply(pd.Series, 1).stack().reset_index(level=1, drop=True)
split_genre.name = 'split_genres'
genre_df = genre_df.drop(['genres'], axis=1).join(split_genre)

# %%
genre_df
# Out:
#          tconst                movie  start_year  runtime_minutes  \
# 0     tt0249516           Foodfight!        2012             91.0
# 0     tt0249516           Foodfight!        2012             91.0
# 0     tt0249516           Foodfight!        2012             91.0
# 1     tt0293429        Mortal Kombat        2021             87.0
# 1     tt0293429        Mortal Kombat        2021             87.0
# ...         ...                  ...         ...              ...
# 3359  tt9805168              Traitor        2015            110.0
# 3360  tt9844102                  Ray        2018            111.0
# 3361  tt9889814  Kiss Kiss Bang Bang        2017             98.0
# 3361  tt9889814  Kiss Kiss Bang Bang        2017             98.0
# 3361  tt9889814  Kiss Kiss Bang Bang        2017             98.0
#
#       production_budget  domestic_gross  worldwide_gross     profit  \
# 0              45000000               0            73706  -44926294
# 0              45000000               0            73706  -44926294
# 0              45000000               0            73706  -44926294
# 1              20000000        70433227        122133227  102133227
# 1              20000000        70433227        122133227  102133227
# ...                 ...             ...              ...        ...
# 3359           22000000        23530831         27882226    5882226
# 3360           40000000        75305995        124823094   84823094
# 3361           15000000         4235837         16829464    1829464
# 3361           15000000         4235837         16829464    1829464
# 3361           15000000         4235837         16829464    1829464
#
#       profitability split_genres
# 0            -60953       Action
# 0            -60953    Animation
# 0            -60953       Comedy
# 1                83       Action
# 1                83    Adventure
# ...             ...          ...
# 3359             21      Romance
# 3360             67        Crime
# 3361             10        Crime
# 3361             10      Romance
# 3361             10     Thriller
#
# [7051 rows x 10 columns]

# %%
genre_df = genre_df.groupby('split_genres').median()
genre_df.reset_index(inplace=True)

genre_df
# Out:
#    split_genres  start_year  runtime_minutes  production_budget  \
# 0        Action      2014.0            107.0         40000000.0
# 1     Adventure      2014.0            104.5         80000000.0
# 2     Animation      2015.0             92.0         75000000.0
# 3     Biography      2015.0            108.0         20000000.0
# 4        Comedy      2014.0             98.0         22000000.0
# 5         Crime      2014.0            105.0         23000000.0
# 6   Documentary      2015.0             74.0         15000000.0
# 7         Drama      2014.0            102.0         15000000.0
# 8        Family      2014.0             95.0         22500000.0
# 9       Fantasy      2014.0            106.0         44000000.0
# 10      History      2014.0            107.0         20000000.0
# 11       Horror      2014.0             92.0         10000000.0
# 12        Music      2014.0            104.0         12000000.0
# 13      Musical      2016.0            100.0         20000000.0
# 14      Mystery      2014.0            100.0         15000000.0
# 15         News      2014.0             60.0         22000000.0
# 16      Romance      2013.0            102.0         15000000.0
# 17       Sci-Fi      2014.0            106.0         35500000.0
# 18        Sport      2014.0            104.5         17000000.0
# 19     Thriller      2014.0             98.0         20000000.0
# 20          War      2014.0            106.0         17500000.0
# 21      Western      2014.5             92.5         18000000.0
#
#     domestic_gross  worldwide_gross       profit  profitability
# 0       36966978.5       84570595.0   36941717.0           48.5
# 1       63972960.0      176301374.5   93003841.5           59.0
# 2       85886987.0      216562312.0  146271037.0           66.0
# 3       15789389.0       28717667.0    9403192.0           40.0
# 4       28848693.0       47213095.0   20641183.0           53.0
# 5       17057897.5       30866066.5    6443980.5           28.5
# 6       11935520.0       23290722.5    5391025.0           33.0
# 7       12900983.5       23726626.0    5415296.0           33.0
# 8       34120192.0       52027776.0   29413772.5           51.5
# 9       40168080.0       89309178.0   45080579.0           55.0
# 10      11538204.0       28400715.0    9403192.0           38.0
# 11      18851821.5       30946408.0   15610910.5           57.0
# 12      13933468.0       19050614.5    8195324.5           50.0
# 13      39440655.0       72071636.0   42527466.0           76.0
# 14      22510790.5       38358851.0   18812286.0           57.0
# 15      15716828.0       46730578.0   28031715.0           26.0
# 16      13960394.0       23251930.0    9867665.0           48.0
# 17      36627423.0       69574072.0   31663530.0           57.0
# 18      12832878.5       21232735.5    1659955.0           22.0
# 19      19594168.5       37095437.0   13718031.0           40.0
# 20       6485961.0       21750000.0    1684207.0           27.0
# 21       4048164.5        8332261.5   -1494927.0          -50.0

# %%
genre_df['profitability'] = ((genre_df['worldwide_gross']-genre_df['production_budget']) / (genre_df['worldwide_gross']))*100
genre_df
# Out:
#    split_genres  start_year  runtime_minutes  production_budget  \
# 0        Action      2014.0            107.0         40000000.0
# 1     Adventure      2014.0            104.5         80000000.0
# 2     Animation      2015.0             92.0         75000000.0
# 3     Biography      2015.0            108.0         20000000.0
# 4        Comedy      2014.0             98.0         22000000.0
# 5         Crime      2014.0            105.0         23000000.0
# 6   Documentary      2015.0             74.0         15000000.0
# 7         Drama      2014.0            102.0         15000000.0
# 8        Family      2014.0             95.0         22500000.0
# 9       Fantasy      2014.0            106.0         44000000.0
# 10      History      2014.0            107.0         20000000.0
# 11       Horror      2014.0             92.0         10000000.0
# 12        Music      2014.0            104.0         12000000.0
# 13      Musical      2016.0            100.0         20000000.0
# 14      Mystery      2014.0            100.0         15000000.0
# 15         News      2014.0             60.0         22000000.0
# 16      Romance      2013.0            102.0         15000000.0
# 17       Sci-Fi      2014.0            106.0         35500000.0
# 18        Sport      2014.0            104.5         17000000.0
# 19     Thriller      2014.0             98.0         20000000.0
# 20          War      2014.0            106.0         17500000.0
# 21      Western      2014.5             92.5         18000000.0
#
#     domestic_gross  worldwide_gross       profit  profitability
# 0       36966978.5       84570595.0   36941717.0      52.702237
# 1       63972960.0      176301374.5   93003841.5      54.623156
# 2       85886987.0      216562312.0  146271037.0      65.367935
# 3       15789389.0       28717667.0    9403192.0      30.356460
# 4       28848693.0       47213095.0   20641183.0      53.402758
# 5       17057897.5       30866066.5    6443980.5      25.484512
# 6       11935520.0       23290722.5    5391025.0      35.596674
# 7       12900983.5       23726626.0    5415296.0      36.779886
# 8       34120192.0       52027776.0   29413772.5      56.753869
# 9       40168080.0       89309178.0   45080579.0      50.732947
# 10      11538204.0       28400715.0    9403192.0      29.579238
# 11      18851821.5       30946408.0   15610910.5      67.686072
# 12      13933468.0       19050614.5    8195324.5      37.009906
# 13      39440655.0       72071636.0   42527466.0      72.249832
# 14      22510790.5       38358851.0   18812286.0      60.895596
# 15      15716828.0       46730578.0   28031715.0      52.921618
# 16      13960394.0       23251930.0    9867665.0      35.489226
# 17      36627423.0       69574072.0   31663530.0      48.975245
# 18      12832878.5       21232735.5    1659955.0      19.934951
# 19      19594168.5       37095437.0   13718031.0      46.085013
# 20       6485961.0       21750000.0    1684207.0      19.540230
# 21       4048164.5        8332261.5   -1494927.0    -116.027785

# %%
plt.figure(figsize=(12, 8))

ax = sns.barplot(x='split_genres', y='profitability', data=genre_df, ci=None, order=genre_df.sort_values('profitability', ascending=False).split_genres)
plt.xticks(rotation=30)
plt.xlabel('Genres', fontsize=20)
plt.ylabel('Profitability', fontsize=20)
plt.title('Profitability by Genre', fontsize=24);

# %% [markdown]
# ## Do ratings affect profitability?
#
#      -Rename primary_title to movie in basics_budgets_df
#      -Split genres as before, join
#      -Plot ratings vs profitability

# %%
basics_ratings_df.rename(columns={'primary_title': 'movie'}, inplace=True)

ratings_budgets_df = basics_ratings_df.merge(budgets_df, how='inner', on='movie')

# %%
ratings_budgets_df
# Out:
#          tconst  averagerating  numvotes                   movie  start_year  \
# 0     tt1043726            4.2     50352  The Legend of Hercules        2014
# 1     tt1094666            7.0      1613              The Hammer        2010
# 2     tt3096900            6.5        13              The Hammer        2015
# 3     tt1171222            5.1      8296           Baggage Claim        2013
# 4     tt1210166            7.6    326657               Moneyball        2011
# ...         ...            ...       ...                     ...         ...
# 2571  tt3517850            8.1        11               12 Rounds        2017
# 2572  tt3591950            5.5        44                Fantasia        2014
# 2573  tt7201846            7.5       705                  Edmond        2018
# 2574  tt8043306            7.4      2724        Teefa in Trouble        2018
# 2575  tt8824064            7.3         7                  Heroes        2019
#
#       runtime_minutes                        genres  production_budget  \
# 0                99.0      Action,Adventure,Fantasy           70000000
# 1               108.0         Biography,Drama,Sport             850000
# 2                75.0  Action,Adventure,Documentary             850000
# 3                96.0                        Comedy            8500000
# 4               133.0         Biography,Drama,Sport           50000000
# ...               ...                           ...                ...
# 2571             87.0          Action,Drama,Romance           20000000
# 2572             86.0                         Drama            2280000
# 2573            110.0          Comedy,Drama,History           10000000
# 2574            155.0           Action,Comedy,Crime            1500000
# 2575             88.0                   Documentary             400000
#
#       domestic_gross  worldwide_gross
# 0           18848538         58953319
# 1             442638           442638
# 2             442638           442638
# 3           21569509         22885836
# 4           75605492        111300835
# ...              ...              ...
# 2571        12234694         17306648
# 2572        83320000         83320000
# 2573          131719           241719
# 2574               0            98806
# 2575          655538           655538
#
# [2576 rows x 10 columns]

# %%
split_ratings = ratings_budgets_df['genres'].str.split(',').apply(pd.Series, 1).stack().reset_index(level=1, drop=True)
split_ratings.name = 'split_genre'
split_ratings = ratings_budgets_df.drop(['genres'], axis=1).join(split_ratings)

# %%
split_ratings
# Out:
#          tconst  averagerating  numvotes                   movie  start_year  \
# 0     tt1043726            4.2     50352  The Legend of Hercules        2014
# 0     tt1043726            4.2     50352  The Legend of Hercules        2014
# 0     tt1043726            4.2     50352  The Legend of Hercules        2014
# 1     tt1094666            7.0      1613              The Hammer        2010
# 1     tt1094666            7.0      1613              The Hammer        2010
# ...         ...            ...       ...                     ...         ...
# 2573  tt7201846            7.5       705                  Edmond        2018
# 2574  tt8043306            7.4      2724        Teefa in Trouble        2018
# 2574  tt8043306            7.4      2724        Teefa in Trouble        2018
# 2574  tt8043306            7.4      2724        Teefa in Trouble        2018
# 2575  tt8824064            7.3         7                  Heroes        2019
#
#       runtime_minutes  production_budget  domestic_gross  worldwide_gross  \
# 0                99.0           70000000        18848538         58953319
# 0                99.0           70000000        18848538         58953319
# 0                99.0           70000000        18848538         58953319
# 1               108.0             850000          442638           442638
# 1               108.0             850000          442638           442638
# ...               ...                ...             ...              ...
# 2573            110.0           10000000          131719           241719
# 2574            155.0            1500000               0            98806
# 2574            155.0            1500000               0            98806
# 2574            155.0            1500000               0            98806
# 2575             88.0             400000          655538           655538
#
#       split_genre
# 0          Action
# 0       Adventure
# 0         Fantasy
# 1       Biography
# 1           Drama
# ...           ...
# 2573      History
# 2574       Action
# 2574       Comedy
# 2574        Crime
# 2575  Documentary
#
# [5842 rows x 10 columns]

# %%
split_ratings_df = split_ratings.groupby('averagerating').mean()
split_ratings_df.reset_index(inplace=True)

split_ratings_df
# Out:
#     averagerating      numvotes   start_year  runtime_minutes  \
# 0             1.6  74978.000000  2011.000000       105.000000
# 1             1.7     70.000000  2013.000000       112.000000
# 2             1.9   4975.600000  2011.600000        87.400000
# 3             2.1   2585.600000  2013.600000       118.800000
# 4             2.3    192.000000  2011.500000        97.500000
# ..            ...           ...          ...              ...
# 70            8.9     13.666667  2013.333333       100.000000
# 71            9.0    249.375000  2012.250000        85.625000
# 72            9.1     28.000000  2016.000000        87.000000
# 73            9.2     39.666667  2014.333333        98.666667
# 74            9.3     22.000000  2018.000000        87.000000
#
#     production_budget  domestic_gross  worldwide_gross
# 0        1.300000e+07    7.301391e+07     9.903412e+07
# 1        2.500000e+07    2.359143e+07     2.986384e+07
# 2        4.500000e+07    8.802518e+06     4.484674e+07
# 3        1.816000e+07    1.833160e+04     1.190800e+05
# 4        1.250000e+07    1.133217e+08     2.633060e+08
# ..                ...             ...              ...
# 70       1.466667e+07    9.905914e+06     1.504065e+07
# 71       3.700000e+07    1.566352e+07     2.840685e+07
# 72       9.200000e+06    2.684904e+06     4.199334e+06
# 73       2.016667e+07    4.316140e+07     7.269130e+07
# 74       1.200000e+07    3.718867e+07     5.700000e+07
#
# [75 rows x 7 columns]

# %%
split_ratings_df['production_budget'] = split_ratings_df['production_budget'].apply(np.int64)
split_ratings_df['domestic_gross'] = split_ratings_df['domestic_gross'].apply(np.int64)
split_ratings_df['worldwide_gross'] = split_ratings_df['worldwide_gross'].apply(np.int64)

# %%
split_ratings_df['profitability'] = ((split_ratings_df['worldwide_gross']-split_ratings_df['production_budget']) / split_ratings_df['worldwide_gross']) * 100
split_ratings_df['profitability'] = split_ratings_df['profitability'].astype(int)

# %%
split_ratings_df
# Out:
#     averagerating      numvotes   start_year  runtime_minutes  \
# 0             1.6  74978.000000  2011.000000       105.000000
# 1             1.7     70.000000  2013.000000       112.000000
# 2             1.9   4975.600000  2011.600000        87.400000
# 3             2.1   2585.600000  2013.600000       118.800000
# 4             2.3    192.000000  2011.500000        97.500000
# ..            ...           ...          ...              ...
# 70            8.9     13.666667  2013.333333       100.000000
# 71            9.0    249.375000  2012.250000        85.625000
# 72            9.1     28.000000  2016.000000        87.000000
# 73            9.2     39.666667  2014.333333        98.666667
# 74            9.3     22.000000  2018.000000        87.000000
#
#     production_budget  domestic_gross  worldwide_gross  profitability
# 0            13000000        73013910         99034125             86
# 1            25000000        23591432         29863840             16
# 2            45000000         8802518         44846742              0
# 3            18160000           18331           119080         -15150
# 4            12500000       113321653        263306000             95
# ..                ...             ...              ...            ...
# 70           14666666         9905913         15040645              2
# 71           37000000        15663519         28406854            -30
# 72            9200000         2684904          4199334           -119
# 73           20166666        43161404         72691298             72
# 74           12000000        37188667         57000000             78
#
# [75 rows x 8 columns]

# %%
ax = sns.regplot(x='averagerating', y='worldwide_gross', data=split_ratings_df)
plt.xlabel('Average Rating')
plt.ylabel('Worldwide Gross (in billions USD)')
plt.title('Average Rating vs Worldwide Gross ');

# %%
np.corrcoef(x=split_ratings_df['averagerating'], y=split_ratings_df['profitability'])
# Out:
# array([[1.        , 0.20458069],
#        [0.20458069, 1.        ]])
